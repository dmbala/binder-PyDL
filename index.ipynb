# %% [markdown]
# # Welcome to an example Binder

# %% [markdown]
# This notebook uses a Python environment with a few libraries, including `tensorflow` and `keras`, all of which were specificied using a `conda` [environment.yml] file.

# %%
# !conda list tensorflow
# Out:
# # packages in environment at /srv/conda/envs/notebook:
# #
# # Name                    Version                   Build  Channel
# tensorflow                2.2.0           mkl_py36h5a57954_0    defaults
# tensorflow-base           2.2.0           mkl_py36hd506778_0    defaults
# tensorflow-datasets       1.2.0                    py36_0    defaults
# tensorflow-estimator      2.4.0              pyh9656e83_0    conda-forge
# tensorflow-gpu            1.5.0                         0    defaults
# tensorflow-gpu-base       1.5.0            py36h8a131e3_0    defaults
# tensorflow-metadata       0.14.0             pyhe6710b0_1    defaults
# tensorflow-tensorboard    1.5.1            py36hf484d3e_1    defaults

# %%
# !conda list keras
# Out:
# # packages in environment at /srv/conda/envs/notebook:
# #
# # Name                    Version                   Build  Channel
# keras                     2.4.3                      py_0    conda-forge
# keras-preprocessing       1.1.2              pyhd8ed1ab_0    conda-forge
